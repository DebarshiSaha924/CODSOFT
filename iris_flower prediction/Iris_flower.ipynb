# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
iris = pd.read_csv('IRIS.csv')

# %%
iris
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sepal_length</th>
#       <th>sepal_width</th>
#       <th>petal_length</th>
#       <th>petal_width</th>
#       <th>species</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>5.1</td>
#       <td>3.5</td>
#       <td>1.4</td>
#       <td>0.2</td>
#       <td>Iris-setosa</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4.9</td>
#       <td>3.0</td>
#       <td>1.4</td>
#       <td>0.2</td>
#       <td>Iris-setosa</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4.7</td>
#       <td>3.2</td>
#       <td>1.3</td>
#       <td>0.2</td>
#       <td>Iris-setosa</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4.6</td>
#       <td>3.1</td>
#       <td>1.5</td>
#       <td>0.2</td>
#       <td>Iris-setosa</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5.0</td>
#       <td>3.6</td>
#       <td>1.4</td>
#       <td>0.2</td>
#       <td>Iris-setosa</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>145</th>
#       <td>6.7</td>
#       <td>3.0</td>
#       <td>5.2</td>
#       <td>2.3</td>
#       <td>Iris-virginica</td>
#     </tr>
#     <tr>
#       <th>146</th>
#       <td>6.3</td>
#       <td>2.5</td>
#       <td>5.0</td>
#       <td>1.9</td>
#       <td>Iris-virginica</td>
#     </tr>
#     <tr>
#       <th>147</th>
#       <td>6.5</td>
#       <td>3.0</td>
#       <td>5.2</td>
#       <td>2.0</td>
#       <td>Iris-virginica</td>
#     </tr>
#     <tr>
#       <th>148</th>
#       <td>6.2</td>
#       <td>3.4</td>
#       <td>5.4</td>
#       <td>2.3</td>
#       <td>Iris-virginica</td>
#     </tr>
#     <tr>
#       <th>149</th>
#       <td>5.9</td>
#       <td>3.0</td>
#       <td>5.1</td>
#       <td>1.8</td>
#       <td>Iris-virginica</td>
#     </tr>
#   </tbody>
# </table>
# <p>150 rows × 5 columns</p>
# </div>

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sepal_length</th>
#       <th>sepal_width</th>
#       <th>petal_length</th>
#       <th>petal_width</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>150.000000</td>
#       <td>150.000000</td>
#       <td>150.000000</td>
#       <td>150.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>5.843333</td>
#       <td>3.054000</td>
#       <td>3.758667</td>
#       <td>1.198667</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>0.828066</td>
#       <td>0.433594</td>
#       <td>1.764420</td>
#       <td>0.763161</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>4.300000</td>
#       <td>2.000000</td>
#       <td>1.000000</td>
#       <td>0.100000</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>5.100000</td>
#       <td>2.800000</td>
#       <td>1.600000</td>
#       <td>0.300000</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>5.800000</td>
#       <td>3.000000</td>
#       <td>4.350000</td>
#       <td>1.300000</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>6.400000</td>
#       <td>3.300000</td>
#       <td>5.100000</td>
#       <td>1.800000</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>7.900000</td>
#       <td>4.400000</td>
#       <td>6.900000</td>
#       <td>2.500000</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
iris.groupby('species').mean()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sepal_length</th>
#       <th>sepal_width</th>
#       <th>petal_length</th>
#       <th>petal_width</th>
#     </tr>
#     <tr>
#       <th>species</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Iris-setosa</th>
#       <td>5.006</td>
#       <td>3.418</td>
#       <td>1.464</td>
#       <td>0.244</td>
#     </tr>
#     <tr>
#       <th>Iris-versicolor</th>
#       <td>5.936</td>
#       <td>2.770</td>
#       <td>4.260</td>
#       <td>1.326</td>
#     </tr>
#     <tr>
#       <th>Iris-virginica</th>
#       <td>6.588</td>
#       <td>2.974</td>
#       <td>5.552</td>
#       <td>2.026</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# # **Data Visualisation**

# %%
sns.scatterplot(x='sepal_length', y='sepal_width', hue='species', data=iris)
plt.show()

# %%
sns.lineplot(data=iris.drop(['species'], axis=1))
plt.show()

# %%
iris.plot.hist(subplots=True, layout=(2,2), figsize=(10, 10), bins=20)
plt.show()

# %%
sns.heatmap(iris.corr(), annot=True)
plt.show()

# %%
g = sns.FacetGrid(iris, col='species')
g = g.map(sns.kdeplot, 'sepal_length')

# %%
sns.pairplot(iris)

# %%
iris.hist(color= 'mediumpurple' ,edgecolor='black',figsize=(10,10))
plt.show()

# %%
iris.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style type="text/css">
# #T_6227a_row0_col0, #T_6227a_row1_col1, #T_6227a_row2_col2, #T_6227a_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6227a_row0_col1 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_6227a_row0_col2 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_6227a_row0_col3 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_6227a_row1_col0, #T_6227a_row1_col2, #T_6227a_row1_col3, #T_6227a_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_6227a_row2_col0 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_6227a_row2_col3 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_6227a_row3_col0 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_6227a_row3_col1 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_6227a_row3_col2 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6227a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6227a_level0_col0" class="col_heading level0 col0" >sepal_length</th>
#       <th id="T_6227a_level0_col1" class="col_heading level0 col1" >sepal_width</th>
#       <th id="T_6227a_level0_col2" class="col_heading level0 col2" >petal_length</th>
#       <th id="T_6227a_level0_col3" class="col_heading level0 col3" >petal_width</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6227a_level0_row0" class="row_heading level0 row0" >sepal_length</th>
#       <td id="T_6227a_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_6227a_row0_col1" class="data row0 col1" >-0.11</td>
#       <td id="T_6227a_row0_col2" class="data row0 col2" >0.87</td>
#       <td id="T_6227a_row0_col3" class="data row0 col3" >0.82</td>
#     </tr>
#     <tr>
#       <th id="T_6227a_level0_row1" class="row_heading level0 row1" >sepal_width</th>
#       <td id="T_6227a_row1_col0" class="data row1 col0" >-0.11</td>
#       <td id="T_6227a_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_6227a_row1_col2" class="data row1 col2" >-0.42</td>
#       <td id="T_6227a_row1_col3" class="data row1 col3" >-0.36</td>
#     </tr>
#     <tr>
#       <th id="T_6227a_level0_row2" class="row_heading level0 row2" >petal_length</th>
#       <td id="T_6227a_row2_col0" class="data row2 col0" >0.87</td>
#       <td id="T_6227a_row2_col1" class="data row2 col1" >-0.42</td>
#       <td id="T_6227a_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_6227a_row2_col3" class="data row2 col3" >0.96</td>
#     </tr>
#     <tr>
#       <th id="T_6227a_level0_row3" class="row_heading level0 row3" >petal_width</th>
#       <td id="T_6227a_row3_col0" class="data row3 col0" >0.82</td>
#       <td id="T_6227a_row3_col1" class="data row3 col1" >-0.36</td>
#       <td id="T_6227a_row3_col2" class="data row3 col2" >0.96</td>
#       <td id="T_6227a_row3_col3" class="data row3 col3" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # **Machine Learning**

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import accuracy_score

# %%
x = iris.drop('species', axis=1)
y= iris.species

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=5)

# %% [markdown]
# ### *K Neighbour Classifier*

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5, p=2, metric='minkowski')
knn.fit(x_train, y_train)

knn.score(x_test, y_test)
# Out:
# 0.9666666666666667

# %% [markdown]
# ### *Logistic Regression*

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(x, y)
y_pred = logreg.predict(x)
print(metrics.accuracy_score(y, y_pred))
# Out:
# 0.9733333333333334

# %% [markdown]
# ### *SVM*

# %%
from sklearn.svm import SVC
svm = SVC(kernel='rbf', random_state=0, gamma=.10, C=1.0)
svm.fit(x_train, y_train)

svm.score(x_test, y_test)
# Out:
# 0.9833333333333333

# %% [markdown]
# ### *Decision Tree Classifier*

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier()
dtree.fit(x_train, y_train)

dtree.score(x_test, y_test)
# Out:
# 0.9666666666666667
